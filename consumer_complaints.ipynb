# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
consumer_complaints = pd.read_csv('complaints_dec_2014.csv')

# %%
consumer_complaints
# Out:
#        Complaint ID                  Product  \
# 0           1177167          Debt collection
# 1           1177166          Debt collection
# 2           1177165          Debt collection
# 3           1177164          Debt collection
# 4           1177163          Debt collection
# 5           1177162          Debt collection
# 6           1177154              Credit card
# 7           1177143          Debt collection
# 8           1177140          Debt collection
# 9           1177139          Debt collection
# 10          1177136          Debt collection
# 11          1177128  Bank account or service
# 12          1177125          Debt collection
# 13          1177124          Debt collection
# 14          1177116          Debt collection
# 15          1177114          Debt collection
# 16          1177196         Credit reporting
# 17          1177113          Debt collection
# 18          1177112          Debt collection
# 19          1177101              Credit card
# ...

# %%
product_counts = consumer_complaints.Product.value_counts()

# %%
product_counts
# Out:
# Mortgage                   3002
# Debt collection            2942
# Credit reporting           2113
# Bank account or service    1136
# Credit card                1100
# Consumer loan               578
# Student loan                340
# Payday loan                 141
# Money transfers             107
# Prepaid card                 70
# Other financial service      14
# dtype: int64

# %%
product_counts.plot(kind = 'bar')

# %%
company_counts = consumer_complaints.Company.value_counts()

# %%
company_counts.head(10).plot(kind = 'bar')

# %%
company_comments = consumer_complaints.Companyresponse.value_counts()

# %%
company_comments.plot(kind = 'bar')

# %%
whatever = 'Companyresponse'

# %%
c
